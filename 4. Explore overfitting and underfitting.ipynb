# %% [markdown]
# https://www.tensorflow.org/tutorials/keras/overfit_and_underfit
#
# In both of the previous examples—classifying movie reviews, and predicting housing prices—we saw that the accuracy of our model on the validation data would peak after training for a number of epochs, and would then start decreasing.
#
# In other words, our model would overfit to the training data. Learning how to deal with overfitting is important. Although it's often possible to achieve high accuracy on the training set, what we really want is to develop models that generalize well to a testing data (or data they haven't seen before).
#
# The opposite of overfitting is underfitting. Underfitting occurs when there is still room for improvement on the test data. This can happen for a number of reasons: If the model is not powerful enough, is over-regularized, or has simply not been trained long enough. This means the network has not learned the relevant patterns in the training data.
#
# If you train for too long though, the model will start to overfit and learn patterns from the training data that don't generalize to the test data. We need to strike a balance. Understanding how to train for an appropriate number of epochs as we'll explore below is a useful skill.
#
# To prevent overfitting, the best solution is to use more training data. A model trained on more data will naturally generalize better. When that is no longer possible, the next best solution is to use techniques like regularization. These place constraints on the quantity and type of information your model can store. If a network can only afford to memorize a small number of patterns, the optimization process will force it to focus on the most prominent patterns, which have a better chance of generalizing well.
#
# In this notebook, we'll explore two common regularization techniques—weight regularization and dropout—and use them to improve our IMDB movie review classification notebook.

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# /Users/petinatan/anaconda3/envs/tensorflow/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# 1.8.0

# %% [markdown]
# Rather than using an embedding as in the previous notebook, here we will multi-hot encode the sentences. This model will quickly overfit to the training set. It will be used to demonstrate when overfitting occurs, and how to fight it.
#
# Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones.

# %%
NUM_WORDS = 10000
(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words = NUM_WORDS)

def multi_hot_sequence(sequences, dimension):
    #create all non-zero matrix of shape (len(sequence), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0
    return results

train_data = multi_hot_sequence(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequence(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %% [markdown]
# Demonstrate overfitting
#
# The simplest way to prevent overfitting is to reduce the size of the model, i.e. the number of learnable parameters in the model (which is determined by the number of layers and the number of units per layer). In deep learning, the number of learnable parameters in a model is often referred to as the model's "capacity". Intuitively, a model with more parameters will have more "memorization capacity" and therefore will be able to easily learn a perfect dictionary-like mapping between training samples and their targets, a mapping without any generalization power, but this would be useless when making predictions on previously unseen data.
#
# Always keep this in mind: deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.
#
# On the other hand, if the network has limited memorization resources, it will not be able to learn the mapping as easily. To minimize its loss, it will have to learn compressed representations that have more predictive power. At the same time, if you make your model too small, it will have difficulty fitting to the training data. There is a balance between "too much capacity" and "not enough capacity".
#
# Unfortunately, there is no magical formula to determine the right size or architecture of your model (in terms of the number of layers, or what the right size for each layer). You will have to experiment using a series of different architectures.
#
# To find an appropriate model size, it's best to start with relatively few layers and parameters, then begin increasing the size of the layers or adding new layers until you see diminishing returns on the validation loss. Let's try this on our movie review classification network.
#
# We'll create a simple model using only Dense layers as a baseline, then create smaller and larger versions, and compare them.

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS, )),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer="adam",
                      loss="binary_crossentropy",
                      metrics=["accuracy", "binary_crossentropy"])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                 train_labels,
                  epochs=20,
                  batch_size=512,
                  validation_data=(test_data, test_labels),
                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.0025 - acc: 1.0000 - binary_crossentropy: 0.0025 - val_loss: 0.8806 - val_acc: 0.8521 - val_binary_crossentropy: 0.8806
# Epoch 2/20
#  - 3s - loss: 0.0020 - acc: 1.0000 - binary_crossentropy: 0.0020 - val_loss: 0.9047 - val_acc: 0.8523 - val_binary_crossentropy: 0.9047
# Epoch 3/20
#  - 3s - loss: 0.0017 - acc: 1.0000 - binary_crossentropy: 0.0017 - val_loss: 0.9338 - val_acc: 0.8515 - val_binary_crossentropy: 0.9338
# Epoch 4/20
#  - 3s - loss: 0.0014 - acc: 1.0000 - binary_crossentropy: 0.0014 - val_loss: 0.9574 - val_acc: 0.8518 - val_binary_crossentropy: 0.9574
# Epoch 5/20
#  - 3s - loss: 0.0011 - acc: 1.0000 - binary_crossentropy: 0.0011 - val_loss: 0.9806 - val_acc: 0.8520 - val_binary_crossentropy: 0.9806
# Epoch 6/20
#  - 3s - loss: 9.4290e-04 - acc: 1.0000 - binary_crossentropy: 9.4290e-04 - val_loss: 1.0038 - val_acc: 0.8520 - val_binary_crossentropy: 1.0038
# Epoch 7/20
#  - 3s - loss: 7.9711e-04 - acc: 1.0000 - binary_crossentropy: 7.9711e-04 - val_loss: 1.0252 - val_acc: 0.8514 - val_binary_crossentropy: 1.0252
# Epoch 8/20
#  - 3s - loss: 6.8141e-04 - acc: 1.0000 - binary_crossentropy: 6.8141e-04 - val_loss: 1.0440 - val_acc: 0.8514 - val_binary_crossentropy: 1.0440
# Epoch 9/20
#  - 3s - loss: 5.8353e-04 - acc: 1.0000 - binary_crossentropy: 5.8353e-04 - val_loss: 1.0627 - val_acc: 0.8515 - val_binary_crossentropy: 1.0627
# Epoch 10/20
#  - 3s - loss: 5.0610e-04 - acc: 1.0000 - binary_crossentropy: 5.0610e-04 - val_loss: 1.0804 - val_acc: 0.8512 - val_binary_crossentropy: 1.0804
# Epoch 11/20
#  - 3s - loss: 4.4162e-04 - acc: 1.0000 - binary_crossentropy: 4.4162e-04 - val_loss: 1.0965 - val_acc: 0.8514 - val_binary_crossentropy: 1.0965
# Epoch 12/20
#  - 3s - loss: 3.9113e-04 - acc: 1.0000 - binary_crossentropy: 3.9113e-04 - val_loss: 1.1111 - val_acc: 0.8511 - val_binary_crossentropy: 1.1111
# Epoch 13/20
#  - 3s - loss: 3.4565e-04 - acc: 1.0000 - binary_crossentropy: 3.4565e-04 - val_loss: 1.1251 - val_acc: 0.8513 - val_binary_crossentropy: 1.1251
# Epoch 14/20
#  - 3s - loss: 3.0949e-04 - acc: 1.0000 - binary_crossentropy: 3.0949e-04 - val_loss: 1.1381 - val_acc: 0.8510 - val_binary_crossentropy: 1.1381
# Epoch 15/20
#  - 3s - loss: 2.7774e-04 - acc: 1.0000 - binary_crossentropy: 2.7774e-04 - val_loss: 1.1506 - val_acc: 0.8510 - val_binary_crossentropy: 1.1506
# Epoch 16/20
#  - 3s - loss: 2.5022e-04 - acc: 1.0000 - binary_crossentropy: 2.5022e-04 - val_loss: 1.1617 - val_acc: 0.8507 - val_binary_crossentropy: 1.1617
# Epoch 17/20
#  - 3s - loss: 2.2724e-04 - acc: 1.0000 - binary_crossentropy: 2.2724e-04 - val_loss: 1.1736 - val_acc: 0.8504 - val_binary_crossentropy: 1.1736
# Epoch 18/20
#  - 3s - loss: 2.0665e-04 - acc: 1.0000 - binary_crossentropy: 2.0665e-04 - val_loss: 1.1843 - val_acc: 0.8503 - val_binary_crossentropy: 1.1843
# Epoch 19/20
#  - 3s - loss: 1.8882e-04 - acc: 1.0000 - binary_crossentropy: 1.8882e-04 - val_loss: 1.1936 - val_acc: 0.8507 - val_binary_crossentropy: 1.1936
# Epoch 20/20
#  - 3s - loss: 1.7312e-04 - acc: 1.0000 - binary_crossentropy: 1.7312e-04 - val_loss: 1.2044 - val_acc: 0.8502 - val_binary_crossentropy: 1.2044

# %% [markdown]
# Create a smaller model
#
# Let's create a model with less hidden units to compare against the baseline model that we just created:

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer="Adam", loss="binary_crossentropy", metrics=["accuracy", "binary_crossentropy"])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 4)                 40004
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                 train_labels,
                  epochs=20,
                  batch_size=512,
                  validation_data=(test_data, test_labels),
                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.5844 - acc: 0.7647 - binary_crossentropy: 0.5844 - val_loss: 0.4842 - val_acc: 0.8542 - val_binary_crossentropy: 0.4842
# Epoch 2/20
#  - 3s - loss: 0.3937 - acc: 0.8867 - binary_crossentropy: 0.3937 - val_loss: 0.3692 - val_acc: 0.8751 - val_binary_crossentropy: 0.3692
# Epoch 3/20
#  - 3s - loss: 0.2964 - acc: 0.9072 - binary_crossentropy: 0.2964 - val_loss: 0.3181 - val_acc: 0.8836 - val_binary_crossentropy: 0.3181
# Epoch 4/20
#  - 3s - loss: 0.2431 - acc: 0.9219 - binary_crossentropy: 0.2431 - val_loss: 0.2946 - val_acc: 0.8867 - val_binary_crossentropy: 0.2946
# Epoch 5/20
#  - 3s - loss: 0.2091 - acc: 0.9326 - binary_crossentropy: 0.2091 - val_loss: 0.2850 - val_acc: 0.8884 - val_binary_crossentropy: 0.2850
# Epoch 6/20
#  - 3s - loss: 0.1842 - acc: 0.9403 - binary_crossentropy: 0.1842 - val_loss: 0.2847 - val_acc: 0.8864 - val_binary_crossentropy: 0.2847
# Epoch 7/20
#  - 3s - loss: 0.1655 - acc: 0.9456 - binary_crossentropy: 0.1655 - val_loss: 0.2909 - val_acc: 0.8828 - val_binary_crossentropy: 0.2909
# Epoch 8/20
#  - 3s - loss: 0.1495 - acc: 0.9528 - binary_crossentropy: 0.1495 - val_loss: 0.2914 - val_acc: 0.8849 - val_binary_crossentropy: 0.2914
# Epoch 9/20
#  - 3s - loss: 0.1359 - acc: 0.9566 - binary_crossentropy: 0.1359 - val_loss: 0.3019 - val_acc: 0.8818 - val_binary_crossentropy: 0.3019
# Epoch 10/20
#  - 3s - loss: 0.1246 - acc: 0.9615 - binary_crossentropy: 0.1246 - val_loss: 0.3111 - val_acc: 0.8793 - val_binary_crossentropy: 0.3111
# Epoch 11/20
#  - 3s - loss: 0.1145 - acc: 0.9660 - binary_crossentropy: 0.1145 - val_loss: 0.3219 - val_acc: 0.8772 - val_binary_crossentropy: 0.3219
# Epoch 12/20
#  - 3s - loss: 0.1056 - acc: 0.9688 - binary_crossentropy: 0.1056 - val_loss: 0.3322 - val_acc: 0.8754 - val_binary_crossentropy: 0.3322
# Epoch 13/20
#  - 3s - loss: 0.0976 - acc: 0.9716 - binary_crossentropy: 0.0976 - val_loss: 0.3449 - val_acc: 0.8744 - val_binary_crossentropy: 0.3449
# Epoch 14/20
#  - 3s - loss: 0.0897 - acc: 0.9744 - binary_crossentropy: 0.0897 - val_loss: 0.3584 - val_acc: 0.8725 - val_binary_crossentropy: 0.3584
# Epoch 15/20
#  - 3s - loss: 0.0829 - acc: 0.9772 - binary_crossentropy: 0.0829 - val_loss: 0.3743 - val_acc: 0.8699 - val_binary_crossentropy: 0.3743
# Epoch 16/20
#  - 2s - loss: 0.0765 - acc: 0.9799 - binary_crossentropy: 0.0765 - val_loss: 0.3927 - val_acc: 0.8672 - val_binary_crossentropy: 0.3927
# Epoch 17/20
#  - 2s - loss: 0.0707 - acc: 0.9823 - binary_crossentropy: 0.0707 - val_loss: 0.4071 - val_acc: 0.8661 - val_binary_crossentropy: 0.4071
# Epoch 18/20
#  - 3s - loss: 0.0650 - acc: 0.9843 - binary_crossentropy: 0.0650 - val_loss: 0.4299 - val_acc: 0.8644 - val_binary_crossentropy: 0.4299
# Epoch 19/20
#  - 3s - loss: 0.0601 - acc: 0.9869 - binary_crossentropy: 0.0601 - val_loss: 0.4428 - val_acc: 0.8637 - val_binary_crossentropy: 0.4428
# Epoch 20/20
#  - 3s - loss: 0.0557 - acc: 0.9885 - binary_crossentropy: 0.0557 - val_loss: 0.4576 - val_acc: 0.8620 - val_binary_crossentropy: 0.4576

# %% [markdown]
# Create a bigger model
#
# As an exercise, you can create an even larger model, and see how quickly it begins overfitting. Next, let's add to this benchmark a network that has much more capacity, far more than the problem would warrant:

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 512)               5120512
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data,
                 train_labels,
                  epochs=20,
                  batch_size=512,
                  validation_data=(test_data, test_labels),
                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 10s - loss: 0.3450 - acc: 0.8522 - binary_crossentropy: 0.3450 - val_loss: 0.2993 - val_acc: 0.8782 - val_binary_crossentropy: 0.2993
# Epoch 2/20
#  - 10s - loss: 0.1434 - acc: 0.9479 - binary_crossentropy: 0.1434 - val_loss: 0.3372 - val_acc: 0.8734 - val_binary_crossentropy: 0.3372
# Epoch 3/20
#  - 10s - loss: 0.0474 - acc: 0.9858 - binary_crossentropy: 0.0474 - val_loss: 0.4580 - val_acc: 0.8671 - val_binary_crossentropy: 0.4580
# Epoch 4/20
#  - 10s - loss: 0.0062 - acc: 0.9992 - binary_crossentropy: 0.0062 - val_loss: 0.5894 - val_acc: 0.8678 - val_binary_crossentropy: 0.5894
# Epoch 5/20
#  - 10s - loss: 0.0011 - acc: 1.0000 - binary_crossentropy: 0.0011 - val_loss: 0.6757 - val_acc: 0.8693 - val_binary_crossentropy: 0.6757
# Epoch 6/20
#  - 10s - loss: 2.4249e-04 - acc: 1.0000 - binary_crossentropy: 2.4249e-04 - val_loss: 0.7199 - val_acc: 0.8698 - val_binary_crossentropy: 0.7199
# Epoch 7/20
#  - 10s - loss: 1.4966e-04 - acc: 1.0000 - binary_crossentropy: 1.4966e-04 - val_loss: 0.7453 - val_acc: 0.8696 - val_binary_crossentropy: 0.7453
# Epoch 8/20
#  - 10s - loss: 1.0774e-04 - acc: 1.0000 - binary_crossentropy: 1.0774e-04 - val_loss: 0.7659 - val_acc: 0.8694 - val_binary_crossentropy: 0.7659
# Epoch 9/20
#  - 10s - loss: 8.2695e-05 - acc: 1.0000 - binary_crossentropy: 8.2695e-05 - val_loss: 0.7809 - val_acc: 0.8697 - val_binary_crossentropy: 0.7809
# Epoch 10/20
#  - 10s - loss: 6.6000e-05 - acc: 1.0000 - binary_crossentropy: 6.6000e-05 - val_loss: 0.7941 - val_acc: 0.8699 - val_binary_crossentropy: 0.7941
# Epoch 11/20
#  - 10s - loss: 5.4052e-05 - acc: 1.0000 - binary_crossentropy: 5.4052e-05 - val_loss: 0.8061 - val_acc: 0.8696 - val_binary_crossentropy: 0.8061
# Epoch 12/20
#  - 10s - loss: 4.5147e-05 - acc: 1.0000 - binary_crossentropy: 4.5147e-05 - val_loss: 0.8161 - val_acc: 0.8699 - val_binary_crossentropy: 0.8161
# Epoch 13/20
#  - 10s - loss: 3.8268e-05 - acc: 1.0000 - binary_crossentropy: 3.8268e-05 - val_loss: 0.8257 - val_acc: 0.8698 - val_binary_crossentropy: 0.8257
# Epoch 14/20
#  - 10s - loss: 3.2844e-05 - acc: 1.0000 - binary_crossentropy: 3.2844e-05 - val_loss: 0.8347 - val_acc: 0.8696 - val_binary_crossentropy: 0.8347
# Epoch 15/20
#  - 10s - loss: 2.8478e-05 - acc: 1.0000 - binary_crossentropy: 2.8478e-05 - val_loss: 0.8418 - val_acc: 0.8700 - val_binary_crossentropy: 0.8418
# Epoch 16/20
#  - 10s - loss: 2.4904e-05 - acc: 1.0000 - binary_crossentropy: 2.4904e-05 - val_loss: 0.8496 - val_acc: 0.8700 - val_binary_crossentropy: 0.8496
# Epoch 17/20
#  - 10s - loss: 2.1970e-05 - acc: 1.0000 - binary_crossentropy: 2.1970e-05 - val_loss: 0.8566 - val_acc: 0.8699 - val_binary_crossentropy: 0.8566
# Epoch 18/20
#  - 9s - loss: 1.9481e-05 - acc: 1.0000 - binary_crossentropy: 1.9481e-05 - val_loss: 0.8631 - val_acc: 0.8701 - val_binary_crossentropy: 0.8631
# Epoch 19/20
#  - 9s - loss: 1.7400e-05 - acc: 1.0000 - binary_crossentropy: 1.7400e-05 - val_loss: 0.8691 - val_acc: 0.8700 - val_binary_crossentropy: 0.8691
# Epoch 20/20
#  - 9s - loss: 1.5593e-05 - acc: 1.0000 - binary_crossentropy: 1.5593e-05 - val_loss: 0.8757 - val_acc: 0.8698 - val_binary_crossentropy: 0.8757

# %% [markdown]
# Plot the training and validation loss
#
# The solid lines show the training loss, and the dashed lines show the validation loss (remember: a lower validation loss indicates a better model). Here, the smaller network begins overfitting later than the baseline model (after 6 epochs rather than 4) and its performance degrades much more slowly once it starts overfitting.

# %%
def plot_history(histories, key="binary_crossentropy"):
    plt.figure(figsize=(16,10))
    for name, history in histories:
        val = plt.plot(history.epoch, history.history["val_" + key],
                      "--", label=name.title() + " Val")
        
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(), label=name.title() + " Train")
        plt.xlabel("Epochs")
        plt.ylabel(key.replace("_", " ").title())
        plt.legend()
        plt.xlim([0, max(history.epoch)])
        

plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# Notice that the larger network begins overfitting almost right away, after just one epoch, and overfits much more severely. The more capacity the network has, the quicker it will be able to model the training data (resulting in a low training loss), but the more susceptible it is to overfitting (resulting in a large difference between the training and validation loss).

# %% [markdown]
# Strategies
#
# Add weight regularization
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# * L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# * L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# In tf.keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
l2_model = keras.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                      activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer="Adam", loss="binary_crossentropy", metrics=["accuracy", "binary_crossentropy"] )
l2_history = l2_model.fit(train_data, train_labels, epochs=20, batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 4s - loss: 0.5655 - acc: 0.7768 - binary_crossentropy: 0.5306 - val_loss: 0.4235 - val_acc: 0.8689 - val_binary_crossentropy: 0.3881
# Epoch 2/20
#  - 3s - loss: 0.3355 - acc: 0.9020 - binary_crossentropy: 0.2948 - val_loss: 0.3445 - val_acc: 0.8860 - val_binary_crossentropy: 0.2997
# Epoch 3/20
#  - 3s - loss: 0.2729 - acc: 0.9233 - binary_crossentropy: 0.2249 - val_loss: 0.3348 - val_acc: 0.8873 - val_binary_crossentropy: 0.2845
# Epoch 4/20
#  - 3s - loss: 0.2429 - acc: 0.9358 - binary_crossentropy: 0.1910 - val_loss: 0.3388 - val_acc: 0.8866 - val_binary_crossentropy: 0.2858
# Epoch 5/20
#  - 3s - loss: 0.2266 - acc: 0.9416 - binary_crossentropy: 0.1721 - val_loss: 0.3491 - val_acc: 0.8812 - val_binary_crossentropy: 0.2938
# Epoch 6/20
#  - 3s - loss: 0.2143 - acc: 0.9480 - binary_crossentropy: 0.1583 - val_loss: 0.3619 - val_acc: 0.8778 - val_binary_crossentropy: 0.3054
# Epoch 7/20
#  - 3s - loss: 0.2043 - acc: 0.9518 - binary_crossentropy: 0.1469 - val_loss: 0.3692 - val_acc: 0.8772 - val_binary_crossentropy: 0.3113
# Epoch 8/20
#  - 3s - loss: 0.1966 - acc: 0.9552 - binary_crossentropy: 0.1381 - val_loss: 0.3799 - val_acc: 0.8760 - val_binary_crossentropy: 0.3211
# Epoch 9/20
#  - 3s - loss: 0.1908 - acc: 0.9559 - binary_crossentropy: 0.1314 - val_loss: 0.3989 - val_acc: 0.8713 - val_binary_crossentropy: 0.3391
# Epoch 10/20
#  - 3s - loss: 0.1830 - acc: 0.9610 - binary_crossentropy: 0.1229 - val_loss: 0.4041 - val_acc: 0.8711 - val_binary_crossentropy: 0.3438
# Epoch 11/20
#  - 3s - loss: 0.1793 - acc: 0.9625 - binary_crossentropy: 0.1186 - val_loss: 0.4223 - val_acc: 0.8690 - val_binary_crossentropy: 0.3612
# Epoch 12/20
#  - 3s - loss: 0.1751 - acc: 0.9642 - binary_crossentropy: 0.1135 - val_loss: 0.4262 - val_acc: 0.8684 - val_binary_crossentropy: 0.3644
# Epoch 13/20
#  - 3s - loss: 0.1685 - acc: 0.9673 - binary_crossentropy: 0.1066 - val_loss: 0.4416 - val_acc: 0.8649 - val_binary_crossentropy: 0.3796
# Epoch 14/20
#  - 3s - loss: 0.1640 - acc: 0.9677 - binary_crossentropy: 0.1019 - val_loss: 0.4511 - val_acc: 0.8633 - val_binary_crossentropy: 0.3889
# Epoch 15/20
#  - 3s - loss: 0.1613 - acc: 0.9690 - binary_crossentropy: 0.0990 - val_loss: 0.4622 - val_acc: 0.8635 - val_binary_crossentropy: 0.3995
# Epoch 16/20
#  - 3s - loss: 0.1582 - acc: 0.9703 - binary_crossentropy: 0.0951 - val_loss: 0.4771 - val_acc: 0.8623 - val_binary_crossentropy: 0.4137
# Epoch 17/20
#  - 3s - loss: 0.1554 - acc: 0.9721 - binary_crossentropy: 0.0916 - val_loss: 0.4853 - val_acc: 0.8627 - val_binary_crossentropy: 0.4214
# Epoch 18/20
#  - 3s - loss: 0.1526 - acc: 0.9725 - binary_crossentropy: 0.0888 - val_loss: 0.5022 - val_acc: 0.8576 - val_binary_crossentropy: 0.4381
# Epoch 19/20
#  - 3s - loss: 0.1511 - acc: 0.9729 - binary_crossentropy: 0.0867 - val_loss: 0.5107 - val_acc: 0.8574 - val_binary_crossentropy: 0.4460
# Epoch 20/20
#  - 3s - loss: 0.1481 - acc: 0.9743 - binary_crossentropy: 0.0833 - val_loss: 0.5221 - val_acc: 0.8584 - val_binary_crossentropy: 0.4571

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_history)])

# %% [markdown]
# As you can see, the L2 regularized model has become much more resistant to overfitting than the baseline model, even though both models have the same number of parameters.

# %% [markdown]
# Add dropout
#
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto. Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1]. The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In tf.keras you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our IMDB network to see how well they do at reducing overfitting:

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.6414 - acc: 0.6314 - binary_crossentropy: 0.6414 - val_loss: 0.5215 - val_acc: 0.8466 - val_binary_crossentropy: 0.5215
# Epoch 2/20
#  - 3s - loss: 0.4702 - acc: 0.8081 - binary_crossentropy: 0.4702 - val_loss: 0.3539 - val_acc: 0.8786 - val_binary_crossentropy: 0.3539
# Epoch 3/20
#  - 3s - loss: 0.3606 - acc: 0.8732 - binary_crossentropy: 0.3606 - val_loss: 0.2956 - val_acc: 0.8871 - val_binary_crossentropy: 0.2956
# Epoch 4/20
#  - 3s - loss: 0.2996 - acc: 0.9017 - binary_crossentropy: 0.2996 - val_loss: 0.2767 - val_acc: 0.8889 - val_binary_crossentropy: 0.2767
# Epoch 5/20
#  - 3s - loss: 0.2515 - acc: 0.9206 - binary_crossentropy: 0.2515 - val_loss: 0.2763 - val_acc: 0.8881 - val_binary_crossentropy: 0.2763
# Epoch 6/20
#  - 3s - loss: 0.2225 - acc: 0.9320 - binary_crossentropy: 0.2225 - val_loss: 0.2868 - val_acc: 0.8863 - val_binary_crossentropy: 0.2868
# Epoch 7/20
#  - 3s - loss: 0.1977 - acc: 0.9391 - binary_crossentropy: 0.1977 - val_loss: 0.3067 - val_acc: 0.8841 - val_binary_crossentropy: 0.3067
# Epoch 8/20
#  - 3s - loss: 0.1768 - acc: 0.9442 - binary_crossentropy: 0.1768 - val_loss: 0.3057 - val_acc: 0.8836 - val_binary_crossentropy: 0.3057
# Epoch 9/20
#  - 3s - loss: 0.1609 - acc: 0.9522 - binary_crossentropy: 0.1609 - val_loss: 0.3435 - val_acc: 0.8804 - val_binary_crossentropy: 0.3435
# Epoch 10/20
#  - 3s - loss: 0.1441 - acc: 0.9566 - binary_crossentropy: 0.1441 - val_loss: 0.3541 - val_acc: 0.8814 - val_binary_crossentropy: 0.3541
# Epoch 11/20
#  - 3s - loss: 0.1327 - acc: 0.9602 - binary_crossentropy: 0.1327 - val_loss: 0.3662 - val_acc: 0.8805 - val_binary_crossentropy: 0.3662
# Epoch 12/20
#  - 3s - loss: 0.1240 - acc: 0.9624 - binary_crossentropy: 0.1240 - val_loss: 0.4017 - val_acc: 0.8794 - val_binary_crossentropy: 0.4017
# Epoch 13/20
#  - 3s - loss: 0.1127 - acc: 0.9675 - binary_crossentropy: 0.1127 - val_loss: 0.3927 - val_acc: 0.8784 - val_binary_crossentropy: 0.3927
# Epoch 14/20
#  - 3s - loss: 0.1042 - acc: 0.9689 - binary_crossentropy: 0.1042 - val_loss: 0.4592 - val_acc: 0.8762 - val_binary_crossentropy: 0.4592
# Epoch 15/20
#  - 3s - loss: 0.1031 - acc: 0.9690 - binary_crossentropy: 0.1031 - val_loss: 0.4623 - val_acc: 0.8753 - val_binary_crossentropy: 0.4623
# Epoch 16/20
#  - 3s - loss: 0.0958 - acc: 0.9715 - binary_crossentropy: 0.0958 - val_loss: 0.4679 - val_acc: 0.8743 - val_binary_crossentropy: 0.4679
# Epoch 17/20
#  - 3s - loss: 0.0953 - acc: 0.9704 - binary_crossentropy: 0.0953 - val_loss: 0.5086 - val_acc: 0.8744 - val_binary_crossentropy: 0.5086
# Epoch 18/20
#  - 3s - loss: 0.0873 - acc: 0.9743 - binary_crossentropy: 0.0873 - val_loss: 0.5128 - val_acc: 0.8736 - val_binary_crossentropy: 0.5128
# Epoch 19/20
#  - 3s - loss: 0.0830 - acc: 0.9754 - binary_crossentropy: 0.0830 - val_loss: 0.5250 - val_acc: 0.8728 - val_binary_crossentropy: 0.5250
# Epoch 20/20
#  - 3s - loss: 0.0795 - acc: 0.9767 - binary_crossentropy: 0.0795 - val_loss: 0.5620 - val_acc: 0.8722 - val_binary_crossentropy: 0.5620

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# Adding dropout is a clear improvement over the baseline model.
